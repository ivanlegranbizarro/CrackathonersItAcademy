# %%
import pandas as pd
import _json

# %% [markdown]
# Archivo descargado de opendatabcn_mercats-centrescomercials_mercats-fires-al-carrer

# %%
fires = pd.read_csv('opendatabcn_mercats-centrescomercials_mercats-fires-al-carrer.csv', encoding='utf-16')

# %% [markdown]
# vemos las columnas y filas que forman el dataset

# %%
fires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   register_id                    47 non-null     object
#  1   name                           47 non-null     object
#  2   institution_id                 0 non-null      float64
#  3   institution_name               0 non-null      float64
#  4   created                        47 non-null     object
#  5   modified                       47 non-null     object
#  6   addresses_roadtype_id          0 non-null      float64
#  7   addresses_roadtype_name        0 non-null      float64
#  8   addresses_road_id              47 non-null     int64
#  9   addresses_road_name            47 non-null     object
#  10  addresses_start_street_number  47 non-null     int64
#  11  addresses_end_street_number    6 non-null      float64
# ...

# %%
columns= fires.columns

# %%
columns
# Out:
# Index(['register_id', 'name', 'institution_id', 'institution_name', 'created',
#        'modified', 'addresses_roadtype_id', 'addresses_roadtype_name',
#        'addresses_road_id', 'addresses_road_name',
#        'addresses_start_street_number', 'addresses_end_street_number',
#        'addresses_neighborhood_id', 'addresses_neighborhood_name',
#        'addresses_district_id', 'addresses_district_name',
#        'addresses_zip_code', 'addresses_town', 'addresses_main_address',
#        'addresses_type', 'values_id', 'values_attribute_id', 'values_category',
#        'values_attribute_name', 'values_value', 'values_outstanding',
#        'values_description', 'secondary_filters_id', 'secondary_filters_name',
#        'secondary_filters_fullpath', 'secondary_filters_tree',
#        'secondary_filters_asia_id', 'geo_epgs_25831_x', 'geo_epgs_25831_y',
#        'geo_epgs_4326_lat', 'geo_epgs_4326_lon', 'estimated_dates',
#        'start_date', 'end_date'],
#       dtype='object')

# %%
fires['geo_epgs_4326_lat']
# Out:
# 0     41.419459
# 1     41.383808
# 2     41.382327
# 3     41.400145
# 4     41.435566
# 5     41.461672
# 6     41.448429
# 7     41.379033
# 8     41.442816
# 9     41.400145
# 10    41.378443
# 11    41.376588
# 12    41.400145
# 13    41.387688
# 14    41.438653
# 15    41.388802
# 16    41.419232
# 17    41.353299
# 18    41.380050
# 19    41.381302
# 20    41.381302
# 21    41.381066
# 22    41.401064
# 23    41.401064
# 24    41.390102
# 25    41.382986
# 26    41.382986
# 27    41.438653
# 28    41.379568
# 29    41.379568
# 30    41.406975
# 31    41.405312
# 32    41.435566
# 33    41.461505
# 34    41.386892
# 35    41.383620
# 36    41.404939
# 37    41.400145
# 38    41.388270
# 39    41.374651
# 40    41.382327
# 41    41.401186
# 42    41.408063
# 43    41.429929
# 44    41.382535
# 45    41.401974
# 46    41.408769
# Name: geo_epgs_4326_lat, dtype: float64

# %% [markdown]
# Cargamos los datos de mercados municipales

# %%
mercats = pd.read_csv('opendatabcn_mercats-centrescomercials_mercats-municipals.csv', encoding='utf-16')
#"C:\Users\34622\Documents\Data Analytics - Cibernarium\Hackaton_comerc_local\opendatabcn_mercats-centrescomercials_mercats-municipals.csv"

# %%
mercats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   register_id                    51 non-null     object
#  1   name                           51 non-null     object
#  2   institution_id                 0 non-null      float64
#  3   institution_name               0 non-null      float64
#  4   created                        51 non-null     object
#  5   modified                       51 non-null     object
#  6   addresses_roadtype_id          0 non-null      float64
#  7   addresses_roadtype_name        0 non-null      float64
#  8   addresses_road_id              51 non-null     int64
#  9   addresses_road_name            51 non-null     object
#  10  addresses_start_street_number  51 non-null     int64
#  11  addresses_end_street_number    3 non-null      float64
# ...

# %% [markdown]
# Hemos concatenado los datasets después de comprobar que tienen las mismas columnas.

# %%
fires_mercats = pd.concat([fires, mercats])

# %% [markdown]
# Buscamos las columnas que tienen nulos. Para empezar eliminamos las columnas que tienen 98 registros nulos, ya que es el mismo número de registros totales.

# %%
fires_mercats.isnull().sum()
# Out:
# register_id                       0
# name                              0
# institution_id                   98
# institution_name                 98
# created                           0
# modified                          0
# addresses_roadtype_id            98
# addresses_roadtype_name          98
# addresses_road_id                 0
# addresses_road_name               0
# addresses_start_street_number     0
# addresses_end_street_number      89
# addresses_neighborhood_id         0
# addresses_neighborhood_name       0
# addresses_district_id             0
# addresses_district_name           0
# addresses_zip_code                0
# addresses_town                    0
# addresses_main_address            0
# addresses_type                   98
# values_id                        20
# values_attribute_id              20
# values_category                  20
# values_attribute_name            20
# values_value                     20
# values_outstanding               20
# ...

# %%
valores_nulos = fires_mercats.isnull().sum()

# %%
valores_nulos.sort_values(ascending= False, inplace=True)

# %%
valores_nulos
# Out:
# addresses_type                   98
# addresses_roadtype_id            98
# start_date                       98
# estimated_dates                  98
# addresses_roadtype_name          98
# end_date                         98
# institution_id                   98
# institution_name                 98
# values_description               91
# addresses_end_street_number      89
# values_category                  20
# values_outstanding               20
# values_attribute_name            20
# values_attribute_id              20
# values_id                        20
# values_value                     20
# secondary_filters_tree            0
# secondary_filters_fullpath        0
# secondary_filters_name            0
# secondary_filters_id              0
# geo_epgs_25831_x                  0
# geo_epgs_25831_y                  0
# geo_epgs_4326_lat                 0
# geo_epgs_4326_lon                 0
# secondary_filters_asia_id         0
# modified                          0
# ...

# %% [markdown]
# eliminamos las columnas con tienen 98 datos nulos o cercanos a ese número, y la columna "register_id", ya que no nos aportan valor

# %%
columnas_eliminar = ['register_id','addresses_type','addresses_roadtype_id','start_date', 'addresses_roadtype_name', 'end_date','estimated_dates',
              'institution_id', 'addresses_end_street_number','institution_name', 'values_description']

# %%
df = fires_mercats.drop(columns=columnas_eliminar)

# %%
df
# Out:
#                                                  name  \
# 0                      Mercat setmanal de  Provençals
# 1                Mercat Gòtic Antiguitats *Plaça Nova
# 2   Fira del Col·lectiu d'Artesans d'Alimentació *...
# 3                       Mostra d'Art *Plaça de Sarrià
# 4                       Fira d'Artesania Rosa de Maig
# ..                                                ...
# 46                                  Mercat Bon Pastor
# 47                                     Mercat Lesseps
# 48                      Mercat Encants de Sant Antoni
# 49                      Mercat Encants de Sant Antoni
# 50                                  Mercat Montserrat
#
#                       created                          modified  \
# 0   1998-07-06T00:00:00+02:00  2024-06-26T14:10:12.961428+02:00
# 1   1996-04-01T00:00:00+02:00  2024-10-03T12:10:48.334415+02:00
# 2   1996-04-01T00:00:00+02:00  2023-09-18T13:19:08.675955+02:00
# ...

# %% [markdown]
# Ahora vamos a decidir que hacemos con estas columnas que tienen datos nulos.
# Nos quedamos solo con las columnas que nos dan información, como son: 'values_attribute_name' y 'values_value' que continen los datos de los teléfonos, o si hacen servicio a domicilio.
#
# values_category                  20
# values_outstanding               20
# values_attribute_name            20
# values_attribute_id              20
# values_id                        20
# values_value                     20

# %%
df[['values_attribute_name','values_value']].tail(50)
# Out:
#    values_attribute_name values_value
# 1             Informació    934132298
# 2                   Tel.    934132307
# 3      Servei a domicili    932694472
# 4                   Tel.    934132308
# 5                   Tel.    934132342
# 6                   Tel.    934132336
# 7                   Tel.    934132332
# 8                   Tel.    934132338
# 9                   Tel.    934132316
# 10                  Tel.    934132304
# 11                  Tel.    934132322
# 12                  Tel.    934132297
# 13                  Tel.    934132305
# 14                  Tel.    934132324
# 15                  Tel.    934132326
# 16                  Tel.    934132326
# 17                  Tel.    934132313
# 18                  Tel.    934132306
# 19                  Tel.    934132309
# 20     Servei a domicili    662002663
# 21                  Tel.    934132327
# 22                  Tel.    934132325
# 23                  Tel.    934132328
# 24                  Tel.    934132328
# ...

# %%
columnas_eliminar2 = ['values_category','values_outstanding', 'values_attribute_id', 'values_id']

# %%
df = df.drop(columns = columnas_eliminar2)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                                  name  \
# 0                      Mercat setmanal de  Provençals
# 1                Mercat Gòtic Antiguitats *Plaça Nova
# 2   Fira del Col·lectiu d'Artesans d'Alimentació *...
# 3                       Mostra d'Art *Plaça de Sarrià
# 4                       Fira d'Artesania Rosa de Maig
# ..                                                ...
# 93                                  Mercat Bon Pastor
# 94                                     Mercat Lesseps
# 95                      Mercat Encants de Sant Antoni
# 96                      Mercat Encants de Sant Antoni
# 97                                  Mercat Montserrat
#
#                       created                          modified  \
# 0   1998-07-06T00:00:00+02:00  2024-06-26T14:10:12.961428+02:00
# 1   1996-04-01T00:00:00+02:00  2024-10-03T12:10:48.334415+02:00
# 2   1996-04-01T00:00:00+02:00  2023-09-18T13:19:08.675955+02:00
# ...

# %% [markdown]
# Estos solo los nulos que nos quedan en el dataset. Que dejamos con un valor NaN a petición de BackEnd

# %%
valores_nulos2 = df.isnull().sum()
valores_nulos2
# Out:
# name                              0
# created                           0
# modified                          0
# addresses_road_id                 0
# addresses_road_name               0
# addresses_start_street_number     0
# addresses_neighborhood_id         0
# addresses_neighborhood_name       0
# addresses_district_id             0
# addresses_district_name           0
# addresses_zip_code                0
# addresses_town                    0
# addresses_main_address            0
# values_attribute_name            20
# values_value                     20
# secondary_filters_id              0
# secondary_filters_name            0
# secondary_filters_fullpath        0
# secondary_filters_tree            0
# secondary_filters_asia_id         0
# geo_epgs_25831_x                  0
# geo_epgs_25831_y                  0
# geo_epgs_4326_lat                 0
# geo_epgs_4326_lon                 0
# dtype: int64

# %%
df.tail(60)
# Out:
#                                                  name  \
# 38         Mercat d'Art Directe *Jardins de Campoamor
# 39             Fira Brocanters *Moll de les Drassanes
# 40  Fira de Productes Tradicionals Catalans *Plaça...
# 41                    Fira d'Artesans Rambla Poblenou
# 42          Fira d'Artesans del Clot *Pl Font i Sagué
# 43   Fira d'Artesania Popular Catalana *Plaça Eivissa
# 44                  Mostra d'Art *Pl Sant Josep Oriol
# 45  Mostra de Pintors Afeccionats *Pl Sagrada Família
# 46                   Fira d'Artesans Placeta de l'Oca
# 47                       Mercat Boqueria - Sant Josep
# 48                              Mercat Santa Caterina
# 49                                 Mercat Hostafrancs
# 50                                       Mercat Sants
# 51                                      Mercat Marina
# 52                                 Mercat Sant Andreu
# 53                            Mercat Ciutat Meridiana
# ...

# %% [markdown]
# Guardamos los datos en archivo JSON para pasarles a BackEnd y puedan empezar a trabajar, mientras seguimos depurando los datos.

# %%
df.to_json('fires_mercats.json', orient='records', lines=True)

# %%
df.to_csv('fires_mercats.csv')

# %% [markdown]
# Eliminamos los duplicados que tienen en el campo con wifi para que no haya redundancias

# %%
fires_mercats_depura = df[df['secondary_filters_name']!= 'WiFi BCN']
fires_mercats_depura.reset_index(drop=True, inplace=True)
fires_mercats_depura
# Out:
#                                                  name  \
# 0                      Mercat setmanal de  Provençals
# 1                Mercat Gòtic Antiguitats *Plaça Nova
# 2   Fira del Col·lectiu d'Artesans d'Alimentació *...
# 3                       Mostra d'Art *Plaça de Sarrià
# 4                       Fira d'Artesania Rosa de Maig
# ..                                                ...
# 89                                  Mercat Bon Pastor
# 90                                     Mercat Lesseps
# 91                      Mercat Encants de Sant Antoni
# 92                      Mercat Encants de Sant Antoni
# 93                                  Mercat Montserrat
#
#                       created                          modified  \
# 0   1998-07-06T00:00:00+02:00  2024-06-26T14:10:12.961428+02:00
# 1   1996-04-01T00:00:00+02:00  2024-10-03T12:10:48.334415+02:00
# 2   1996-04-01T00:00:00+02:00  2023-09-18T13:19:08.675955+02:00
# ...

# %% [markdown]
# Aquí añadimos las webs de cada mercado para poder consultar los horarios de apertura.

# %%
links = {
    "Mercat setmanal de Provençals": "https://www.xn--mercatprovenals-pmb.com/",
    "Mercat Gòtic Antiguitats *Plaça Nova": "https://ajuntament.barcelona.cat/jovesbarcelona/caaj/es/detail/mercat-gotic-antiguitats-placa-nova_96092125659",
    "Fira del Col·lectiu d'Artesans d'Alimentació *Plaça del Pi": "https://guia.barcelona.cat/es/detall/fira-del-collectiu-d-artesans-d-alimentacio-placa-del-pi_99400686952.html",
    "Mostra d'Art *Plaça de Sarrià": "https://guia.barcelona.cat/es/detall/mostra-d-art-placa-de-sarria_99400159418.html",
    "Fira d'Artesania Rosa de Maig": "https://ajuntament.barcelona.cat/jovesbarcelona/caaj/es/detail/fira-d-artesania-rosa-de-maig_99400478617.html",
    "Petit Mercat de Zona Nord": "https://ajuntament.barcelona.cat/es/detall/petit-mercat-zona-nord_99400256451.html",
    "Petit Mercat de Trinitat Nova": "https://ajuntament.barcelona.cat/es/detall/petit-mercat-trinitat-nova_99400256452.html",
    "Mercat del Vell *Estació de Sants": "https://ajuntament.barcelona.cat/jovesbarcelona/caaj/es/detail/mercat-del-vell-estacio-de-sants_99400556374.html",
    "Petit Mercat de Canyelles": "https://www.barcelona.cat/casalsdebarri/verdun/es/detail/petit-mercat-de-canyelles_96353173651",
    "Fira de Llibre Vell *Plaça de Sarrià": "https://guia.barcelona.cat/ca/detall/fira-del-llibre-vell-a-la-placa-de-sarria_99400322558.html",
    "Mostra de Pintors, Caricaturistes i Retratistes de les Rambles": "https://guia.barcelona.cat/es/detall/mostra-de-pintors-caricaturistes-i-retratistes_99400686938.html",
    "Fira Nova Artesania *Rambles": "https://guia.barcelona.cat/es/detall/fira-d-artesania_99400686927.html",
    "Fira d'Embotits Artesanals *Plaça de Sarrià": "https://guia.barcelona.cat/es/detall/fira-d-embotits-artesanals_99400159424.html",
    "Fira d'Artesans Plaça Sant Agustí Vell": "https://guia.barcelona.cat/es/detall/fira-d-artesans_99400256431.html",
    "Fira d'Artesans Nou Barris": "https://guia.barcelona.cat/es/detall/fira-d-artesans-nou-barris_98096114839.html",
    "Fira Espai d'Art *Av Diagonal": "https://guia.barcelona.cat/es/detall/fira-espai-d-art_99400556370.html",
    "Mercat Setmanal del Besòs": "https://www.mercatsetmanal.cat",
    "Mercat setmanal de la Marina-Zona Franca": "https://ajuntament.barcelona.cat/sants-montjuic/es/el-distrito-y-sus-barrios/sants-badal/agenda/mercat-setmanal-de-la-marina-zona-franca_99400322547",
"https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-sant-antoni",
    "Mercat Les Corts": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-les-corts",
    "Mercat Galvany": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-galvany",
    "Mercat Llibertat": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-llibertat",
    "Mercat Carmel": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-carmel",
    "Mercat Trinitat": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-trinitat",
    "Mercat Felip II": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-felip-ii",
    "Mercat de les Flors *Les Rambles": "https://ajuntament.barcelona.cat/mercats/es/",
    "Mercat Dominical de Sant Antoni": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-dominical-de-sant-antoni",
    "Mercat Núria": "https://ajuntament.barcelona.cat/mercats/es/",
    "Mercat Estrella": "https://ajuntament.barcelona.cat/mercats/es/",
    "Mercat Vall d'Hebron - Taxonera": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-vall-dhebron",
    "Mercat Horta": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-horta",
    "Mercat Mercè": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-merce",
    "Mercat Bon Pastor": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-bon-pastor",
    "Mercat Lesseps": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-lesseps",
    "Mercat Encants de Sant Antoni": "https://ajuntament.barcelona.cat/mercats/es/",
    "Mercat Montserrat": "https://ajuntament.barcelona.cat/mercats/es/mercado/mercat-montserrat"
    
}


fires_mercats_depura['Source Link'] = fires_mercats_depura['name'].map(links)

fires_mercats_depura.head()
# Out:
# C:\Users\34622\AppData\Local\Temp\ipykernel_13888\3926486715.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_mercats_depura['Source Link'] = fires_mercats_depura['name'].map(links)
#                                                 name  \
# 0                     Mercat setmanal de  Provençals
# 1               Mercat Gòtic Antiguitats *Plaça Nova
# 2  Fira del Col·lectiu d'Artesans d'Alimentació *...
# 3                      Mostra d'Art *Plaça de Sarrià
# 4                      Fira d'Artesania Rosa de Maig
#
#                      created                          modified  \
# 0  1998-07-06T00:00:00+02:00  2024-06-26T14:10:12.961428+02:00
# 1  1996-04-01T00:00:00+02:00  2024-10-03T12:10:48.334415+02:00
# ...

# %% [markdown]
# En base a las columnas que han seleccionado en BackEnd, vamos a renombrarlas y quedarnos con las que ellos van a utilizar, que son las siguientes:
# table->id();
#             $table->string('name')->unique();
#             $table->date('date_creation');
#             $table->string('address');
#             $table->string('address_number');
#             $table->string('neighborhood');
#             $table->string('districtdistrict');
#             $table->string('zip_code');
#             $table->string('town');
#             $table->string('phone')->nullable();
#             $table->string('schedule');
#             $table->enum('type',['market', 'fair']);
#             coord_lat
#             cood_lon
#             $table->timestamps();

# %% [markdown]
# Hemos añadido un campo nuevo con valor único: Barcelona, por si en un futuro se quiere ampliar el ámbito de representación.

# %%
fires_mercats_depura['Ciudad'] = 'Barcelona'
# Out:
# C:\Users\34622\AppData\Local\Temp\ipykernel_13888\377581292.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_mercats_depura['Ciudad'] = 'Barcelona'

# %%
fires_mercats_depura
# Out:
#                                                  name  \
# 0                      Mercat setmanal de  Provençals
# 1                Mercat Gòtic Antiguitats *Plaça Nova
# 2   Fira del Col·lectiu d'Artesans d'Alimentació *...
# 3                       Mostra d'Art *Plaça de Sarrià
# 4                       Fira d'Artesania Rosa de Maig
# ..                                                ...
# 89                                  Mercat Bon Pastor
# 90                                     Mercat Lesseps
# 91                      Mercat Encants de Sant Antoni
# 92                      Mercat Encants de Sant Antoni
# 93                                  Mercat Montserrat
#
#                       created                          modified  \
# 0   1998-07-06T00:00:00+02:00  2024-06-26T14:10:12.961428+02:00
# 1   1996-04-01T00:00:00+02:00  2024-10-03T12:10:48.334415+02:00
# 2   1996-04-01T00:00:00+02:00  2023-09-18T13:19:08.675955+02:00
# ...

# %% [markdown]
# Hemos renombrado los campos

# %%
fires_mercats_depura.rename(columns = {'created':'date_creation'}, inplace = True)
fires_mercats_depura.rename(columns = {'addresses_road_name':'address'}, inplace = True)
fires_mercats_depura.rename(columns = {'addresses_start_street_number':'address_number'}, inplace = True)
fires_mercats_depura.rename(columns = {'addresses_neighborhood_name':'neighborhood'}, inplace = True)
fires_mercats_depura.rename(columns = {'addresses_district_name':'district'}, inplace = True)
fires_mercats_depura.rename(columns = {'addresses_neighborhood_id':'zip_code'}, inplace = True)
fires_mercats_depura.rename(columns = {'Ciudad':'town'}, inplace = True)
fires_mercats_depura.rename(columns = {'values_value':'phone'}, inplace = True)
fires_mercats_depura.rename(columns = {'Source Link':'schedule'}, inplace = True)
fires_mercats_depura.rename(columns = {'secondary_filters_name':'enum'}, inplace = True)
fires_mercats_depura.rename(columns = {'geo_epgs_4326_lat':'coord_lat'}, inplace = True)
fires_mercats_depura.rename(columns = {'geo_epgs_4326_lon':'coord_lon'}, inplace = True)
fires_mercats_depura.rename(columns = {'secondary_filters_name':'enum'}, inplace = True)
#fires_mercats_depura.drop(columns = ['modified','addresses_road_id', 'addresses_neighborhood_id'])
# Out:
# C:\Users\34622\AppData\Local\Temp\ipykernel_13888\3882462913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_mercats_depura.rename(columns = {'created':'date_creation'}, inplace = True)
# C:\Users\34622\AppData\Local\Temp\ipykernel_13888\3882462913.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_mercats_depura.rename(columns = {'addresses_road_name':'address'}, inplace = True)
# C:\Users\34622\AppData\Local\Temp\ipykernel_13888\3882462913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# Selecionamos los campos que vamos a utilizar en el desarrollo

# %%
fires_mercats_depura2 = fires_mercats_depura[['name','date_creation','address','address_number', 'neighborhood', 'district','zip_code', 'town', 'phone', 
                      'schedule', 'enum','coord_lat','coord_lon']]

# %% [markdown]
# Modificamos el formato de fecha de creación para facilitar la comprensión.

# %%
fires_mercats_depura2['date_creation'] = fires_mercats_depura2['date_creation'].str.split('T').str[0]
fires_mercats_depura2
# Out:
# C:\Users\34622\AppData\Local\Temp\ipykernel_13888\2408229899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_mercats_depura2['date_creation'] = fires_mercats_depura2['date_creation'].str.split('T').str[0]
#                                                  name date_creation  \
# 0                      Mercat setmanal de  Provençals    1998-07-06
# 1                Mercat Gòtic Antiguitats *Plaça Nova    1996-04-01
# 2   Fira del Col·lectiu d'Artesans d'Alimentació *...    1996-04-01
# 3                       Mostra d'Art *Plaça de Sarrià    1996-04-02
# 4                       Fira d'Artesania Rosa de Maig    1997-12-19
# ..                                                ...           ...
# ...

# %%
nuevo_orden = ['name','date_creation','address','address_number', 'neighborhood', 'district','zip_code', 'town','coord_lat','coord_lon', 'phone','schedule', 'enum']  # Reemplaza con el orden que desees
fires_mercats_final = fires_mercats_depura2[nuevo_orden]

# %%
fires_mercats_final
# Out:
#                                                  name date_creation  \
# 0                      Mercat setmanal de  Provençals    1998-07-06
# 1                Mercat Gòtic Antiguitats *Plaça Nova    1996-04-01
# 2   Fira del Col·lectiu d'Artesans d'Alimentació *...    1996-04-01
# 3                       Mostra d'Art *Plaça de Sarrià    1996-04-02
# 4                       Fira d'Artesania Rosa de Maig    1997-12-19
# ..                                                ...           ...
# 89                                  Mercat Bon Pastor    1985-01-17
# 90                                     Mercat Lesseps    1984-12-28
# 91                      Mercat Encants de Sant Antoni    1984-12-28
# 92                      Mercat Encants de Sant Antoni    1984-12-28
# 93                                  Mercat Montserrat    1985-01-17
#
#              address  address_number              neighborhood  \
# 0          C Menorca              19  Sant Martí de Provençals
# ...

# %% [markdown]
# Se eliminan registros duplicados

# %%
fires_mercats_final.drop_duplicates(inplace= True)
# Out:
# C:\Users\34622\AppData\Local\Temp\ipykernel_13888\2581548854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_mercats_final.drop_duplicates(inplace= True)

# %%
fires_mercats_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86 entries, 0 to 93
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            86 non-null     object
#  1   date_creation   86 non-null     object
#  2   address         86 non-null     object
#  3   address_number  86 non-null     int64
#  4   neighborhood    86 non-null     object
#  5   district        86 non-null     object
#  6   zip_code        86 non-null     int64
#  7   town            86 non-null     object
#  8   coord_lat       86 non-null     float64
#  9   coord_lon       86 non-null     float64
#  10  phone           66 non-null     object
#  11  schedule        82 non-null     object
#  12  enum            86 non-null     object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 9.4+ KB

# %% [markdown]
# En el campo Phone, hemos dejado los NaN a petición del equipo de BackEnd. Los datos con un guión son los que no tienen teléfono.

# %%
fires_mercats_final.to_csv('fires_mercats_final.csv')

# %%
fires_mercats_final.to_json('nou.json', orient='records', lines=True)

# %%
fires_mercats_final.to_json('fires_mercats_final_split.json', orient='split')
fires_mercats_final.to_json('fires_mercats_final_records.json', orient='records')
fires_mercats_final.to_json('fires_mercats_final_index.json', orient='index')
fires_mercats_final.to_json('fires_mercats_final_columns.json', orient='columns')
fires_mercats_final.to_json('fires_mercats_final_values.json', orient='values')
fires_mercats_final.to_json('fires_mercats_final_table.json', orient='table')

# %% [markdown]
# #### Visualizaciones

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
green_palette = ['#2ca02c','#98df8a']

# %%
plt.figure(figsize = (12,7))
ax = sns.countplot(data = fires_mercats_final, x = 'district', palette= green_palette, hue = 'enum')
ax.bar_label(ax.containers[0], fontsize = 10)
ax.bar_label(ax.containers[1], fontsize = 10)
plt.xlabel('Districte')
plt.ylabel('Núm Mercats')
plt.title('Número de Mercats per districte de Barcelona')
plt.xticks(rotation=80)  
plt.tight_layout()

# %% [markdown]
# Podemos observar que el distrito Ciutat Vella es el que más concentración de Mercats i Fires al carrer tienen con 12 fires. Por otro lado, el distrito con más Mercats Municipals es Eixample con un valor de 8.
# Los distritos de Sant Andreu (2 firas), Sants-Monjuic (2 firas) i Horta-Guinardó (1 fira) son los que tienen una menor presencia de firas en Barcelona.
# Destaca el distrito de Les Corts por sólo tener un Mercado Municipal.

# %%
fires = fires_mercats_final[fires_mercats_final['enum']== 'Mercats i fires al carrer']

# %%
fires.reset_index()

# %%
fires2 = fires.groupby('district').enum.count()
fires2 =fires2.reset_index()
fires2
# Out:
#               district  enum
# 0         Ciutat Vella    12
# 1             Eixample     5
# 2       Horta-Guinardó     1
# 3            Les Corts     4
# 4           Nou Barris     6
# 5          Sant Andreu     2
# 6           Sant Martí     5
# 7       Sants-Montjuïc     2
# 8  Sarrià-Sant Gervasi     6

# %%
colores_verdes = [
    "#98FB98",
    "#00FF00",
    "#32CD32",
    "#228B22",
    "#6B8E23",
    "#2E8B57",
    "#3CB371",
    "#00FA9A",
    "#7FFF00",
    "#ADFF2F",
    "#4B0082",
    "#008000" 
]

# %%
plt.figure(figsize = (12,7))
plt.pie(data = fires2, x = 'enum', labels = 'district', autopct='%1.1f%%', colors = colores_verdes)
plt.title('Número de Fires i Mercats al carrer per districte de Barcelona')
# Out:
# Text(0.5, 1.0, 'Número de Fires i Mercats al carrer per districte de Barcelona')

# %% [markdown]
# Se ha representado los porcentages de Firas que hay en cada distrito, ya que es el valor que nos diferencia de Mercats de Barcelona.
